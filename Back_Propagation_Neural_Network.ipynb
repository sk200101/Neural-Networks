# %%
#import libraries
import numpy as np

# %%
X = np.array(([2,9], [1,5], [3,6]), dtype=float)
y = np.array(([92], [86], [89]), dtype=float)
X = X/np.max(X,axis=0)  # maximum of X array longitudinally
y = y/100

# %%
print(y)
# Out:
# [[0.92]
#  [0.86]
#  [0.89]]

# %%
# Sigmoid function
def sigmoid (x):
    return 1/(1 + np.exp(-x))

# %%
# Derivative of Sigmoid function
def derivatives_sigmoid(x):
    return x * (1 - x)

# %%
# Variable initialization
epoch = 200 # Setting training iterations
lr = 0.5 # Setting learning rate

# %%
inputlayer_neurons = 2 # number of features in data set
hiddenlayer_neurons = 3 # number of hidden layers neurons
output_neurons = 1
# weight and bias initialization

# %%
wh = np.random.uniform(size=(inputlayer_neurons,hiddenlayer_neurons))
bh = np.random.uniform(size=(1,hiddenlayer_neurons))
wout = np.random.uniform(size=(hiddenlayer_neurons,output_neurons))
bout = np.random.uniform(size=(1,output_neurons))

# %%
# draws a random range of numbers uniformly of dim x*y
for i in range(epoch):
    #Forward Propagation
    hinp1 = np.dot(X,wh)
    hinp = hinp1 + bh
    hlayer_act = sigmoid(hinp)
    outinp1 = np.dot(hlayer_act,wout)
    outinp = outinp1 + bout
    output = sigmoid(outinp)
    
    # Backpropagation
    EO = y - output
    outgrad = derivatives_sigmoid(output)
    d_output = EO * outgrad
    EH = d_output.dot(wout.T)
    hiddengrad = derivatives_sigmoid(hlayer_act) # how much hidden layer wts contributed to error
    
    d_hiddenlayer = EH * hiddengrad
    
    wout += hlayer_act.T.dot(d_output) *lr
    
    wh += X.T.dot(d_hiddenlayer) *lr
    
    print("-------------Iteration--", i+1,"Starts-------------")
    print("Input: \n" + str(X))
    print("Actual Output: \n" + str(y))
    print("Predicted Output: \n", output)
    print("-------------Iteration--", i+1,"Ends---------------\n")
    
print("Input: \n" + str(X))
print("Actual Output: \n" + str(y))
print("Predicted Output: \n", output)
# Out:
# -------------Iteration-- 1 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.91035636]
#  [0.89753075]
#  [0.90968319]]
# -------------Iteration-- 1 Ends---------------
#
# -------------Iteration-- 2 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.91002173]
#  [0.89719114]
#  [0.90934595]]
# -------------Iteration-- 2 Ends---------------
#
# -------------Iteration-- 3 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.90969214]
#  [0.89685676]
#  [0.90901378]]
# -------------Iteration-- 3 Ends---------------
#
# -------------Iteration-- 4 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.9093676 ]
#  [0.89652763]
#  [0.90868669]]
# -------------Iteration-- 4 Ends---------------
#
# -------------Iteration-- 5 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.90904811]
#  [0.89620373]
#  [0.90836469]]
# -------------Iteration-- 5 Ends---------------
#
# -------------Iteration-- 6 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.90873368]
#  [0.89588506]
#  [0.90804777]]
# -------------Iteration-- 6 Ends---------------
#
# -------------Iteration-- 7 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.9084243 ]
#  [0.89557162]
#  [0.90773594]]
# -------------Iteration-- 7 Ends---------------
#
# -------------Iteration-- 8 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.90811996]
#  [0.89526338]
#  [0.90742918]]
# -------------Iteration-- 8 Ends---------------
#
# -------------Iteration-- 9 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.90782065]
#  [0.89496034]
#  [0.9071275 ]]
# -------------Iteration-- 9 Ends---------------
#
# -------------Iteration-- 10 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.90752637]
#  [0.89466247]
#  [0.90683086]]
# -------------Iteration-- 10 Ends---------------
#
# -------------Iteration-- 11 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.90723709]
#  [0.89436976]
#  [0.90653926]]
# -------------Iteration-- 11 Ends---------------
#
# -------------Iteration-- 12 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.9069528 ]
#  [0.89408217]
#  [0.90625268]]
# -------------Iteration-- 12 Ends---------------
#
# -------------Iteration-- 13 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.90667347]
#  [0.89379969]
#  [0.9059711 ]]
# -------------Iteration-- 13 Ends---------------
#
# -------------Iteration-- 14 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.90639908]
#  [0.89352227]
#  [0.90569449]]
# -------------Iteration-- 14 Ends---------------
#
# -------------Iteration-- 15 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.90612961]
#  [0.8932499 ]
#  [0.90542283]]
# -------------Iteration-- 15 Ends---------------
#
# -------------Iteration-- 16 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.90586502]
#  [0.89298253]
#  [0.90515607]]
# -------------Iteration-- 16 Ends---------------
#
# -------------Iteration-- 17 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.90560527]
#  [0.89272013]
#  [0.9048942 ]]
# -------------Iteration-- 17 Ends---------------
#
# -------------Iteration-- 18 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.90535035]
#  [0.89246265]
#  [0.90463718]]
# -------------Iteration-- 18 Ends---------------
#
# -------------Iteration-- 19 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.9051002 ]
#  [0.89221006]
#  [0.90438497]]
# -------------Iteration-- 19 Ends---------------
#
# -------------Iteration-- 20 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.90485479]
#  [0.89196231]
#  [0.90413753]]
# -------------Iteration-- 20 Ends---------------
#
# -------------Iteration-- 21 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.90461408]
#  [0.89171936]
#  [0.90389481]]
# -------------Iteration-- 21 Ends---------------
#
# -------------Iteration-- 22 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.90437803]
#  [0.89148116]
#  [0.90365679]]
# -------------Iteration-- 22 Ends---------------
#
# -------------Iteration-- 23 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.90414659]
#  [0.89124767]
#  [0.9034234 ]]
# -------------Iteration-- 23 Ends---------------
#
# -------------Iteration-- 24 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.90391971]
#  [0.89101882]
#  [0.90319461]]
# -------------Iteration-- 24 Ends---------------
#
# -------------Iteration-- 25 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.90369735]
#  [0.89079457]
#  [0.90297037]]
# -------------Iteration-- 25 Ends---------------
#
# -------------Iteration-- 26 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.90347946]
#  [0.89057487]
#  [0.90275062]]
# -------------Iteration-- 26 Ends---------------
#
# -------------Iteration-- 27 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.90326599]
#  [0.89035965]
#  [0.90253532]]
# -------------Iteration-- 27 Ends---------------
#
# -------------Iteration-- 28 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.90305688]
#  [0.89014888]
#  [0.90232441]]
# -------------Iteration-- 28 Ends---------------
#
# -------------Iteration-- 29 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.90285208]
#  [0.88994248]
#  [0.90211784]]
# -------------Iteration-- 29 Ends---------------
#
# -------------Iteration-- 30 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.90265154]
#  [0.88974041]
#  [0.90191556]]
# -------------Iteration-- 30 Ends---------------
#
# -------------Iteration-- 31 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.9024552 ]
#  [0.8895426 ]
#  [0.90171751]]
# -------------Iteration-- 31 Ends---------------
#
# -------------Iteration-- 32 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.90226301]
#  [0.889349  ]
#  [0.90152363]]
# -------------Iteration-- 32 Ends---------------
#
# -------------Iteration-- 33 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.90207491]
#  [0.88915954]
#  [0.90133387]]
# -------------Iteration-- 33 Ends---------------
#
# -------------Iteration-- 34 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.90189084]
#  [0.88897417]
#  [0.90114817]]
# -------------Iteration-- 34 Ends---------------
#
# -------------Iteration-- 35 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.90171075]
#  [0.88879282]
#  [0.90096646]]
# -------------Iteration-- 35 Ends---------------
#
# -------------Iteration-- 36 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.90153457]
#  [0.88861544]
#  [0.9007887 ]]
# -------------Iteration-- 36 Ends---------------
#
# -------------Iteration-- 37 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.90136225]
#  [0.88844196]
#  [0.90061482]]
# -------------Iteration-- 37 Ends---------------
#
# -------------Iteration-- 38 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.90119372]
#  [0.88827232]
#  [0.90044476]]
# -------------Iteration-- 38 Ends---------------
#
# -------------Iteration-- 39 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.90102894]
#  [0.88810645]
#  [0.90027847]]
# -------------Iteration-- 39 Ends---------------
#
# -------------Iteration-- 40 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.90086783]
#  [0.8879443 ]
#  [0.90011587]]
# -------------Iteration-- 40 Ends---------------
#
# -------------Iteration-- 41 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.90071033]
#  [0.88778581]
#  [0.89995692]]
# -------------Iteration-- 41 Ends---------------
#
# -------------Iteration-- 42 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.9005564 ]
#  [0.88763091]
#  [0.89980155]]
# -------------Iteration-- 42 Ends---------------
#
# -------------Iteration-- 43 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.90040596]
#  [0.88747953]
#  [0.8996497 ]]
# -------------Iteration-- 43 Ends---------------
#
# -------------Iteration-- 44 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.90025896]
#  [0.88733163]
#  [0.8995013 ]]
# -------------Iteration-- 44 Ends---------------
#
# -------------Iteration-- 45 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.90011533]
#  [0.88718713]
#  [0.89935631]]
# -------------Iteration-- 45 Ends---------------
#
# -------------Iteration-- 46 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89997503]
#  [0.88704597]
#  [0.89921465]]
# -------------Iteration-- 46 Ends---------------
#
# -------------Iteration-- 47 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89983798]
#  [0.8869081 ]
#  [0.89907628]]
# -------------Iteration-- 47 Ends---------------
#
# -------------Iteration-- 48 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89970412]
#  [0.88677345]
#  [0.89894112]]
# -------------Iteration-- 48 Ends---------------
#
# -------------Iteration-- 49 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89957341]
#  [0.88664196]
#  [0.89880912]]
# -------------Iteration-- 49 Ends---------------
#
# -------------Iteration-- 50 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89944577]
#  [0.88651357]
#  [0.89868022]]
# -------------Iteration-- 50 Ends---------------
#
# -------------Iteration-- 51 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89932116]
#  [0.88638823]
#  [0.89855437]]
# -------------Iteration-- 51 Ends---------------
#
# -------------Iteration-- 52 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89919951]
#  [0.88626586]
#  [0.89843149]]
# -------------Iteration-- 52 Ends---------------
#
# -------------Iteration-- 53 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89908077]
#  [0.88614642]
#  [0.89831154]]
# -------------Iteration-- 53 Ends---------------
#
# -------------Iteration-- 54 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89896487]
#  [0.88602984]
#  [0.89819446]]
# -------------Iteration-- 54 Ends---------------
#
# -------------Iteration-- 55 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89885176]
#  [0.88591607]
#  [0.89808018]]
# -------------Iteration-- 55 Ends---------------
#
# -------------Iteration-- 56 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89874139]
#  [0.88580505]
#  [0.89796866]]
# -------------Iteration-- 56 Ends---------------
#
# -------------Iteration-- 57 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.8986337 ]
#  [0.88569672]
#  [0.89785984]]
# -------------Iteration-- 57 Ends---------------
#
# -------------Iteration-- 58 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89852864]
#  [0.88559104]
#  [0.89775366]]
# -------------Iteration-- 58 Ends---------------
#
# -------------Iteration-- 59 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89842615]
#  [0.88548793]
#  [0.89765007]]
# -------------Iteration-- 59 Ends---------------
#
# -------------Iteration-- 60 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89832617]
#  [0.88538735]
#  [0.89754901]]
# -------------Iteration-- 60 Ends---------------
#
# -------------Iteration-- 61 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89822866]
#  [0.88528925]
#  [0.89745043]]
# -------------Iteration-- 61 Ends---------------
#
# -------------Iteration-- 62 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89813356]
#  [0.88519357]
#  [0.89735428]]
# -------------Iteration-- 62 Ends---------------
#
# -------------Iteration-- 63 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89804082]
#  [0.88510025]
#  [0.89726051]]
# -------------Iteration-- 63 Ends---------------
#
# -------------Iteration-- 64 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89795039]
#  [0.88500926]
#  [0.89716906]]
# -------------Iteration-- 64 Ends---------------
#
# -------------Iteration-- 65 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89786221]
#  [0.88492053]
#  [0.89707988]]
# -------------Iteration-- 65 Ends---------------
#
# -------------Iteration-- 66 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89777625]
#  [0.88483401]
#  [0.89699293]]
# -------------Iteration-- 66 Ends---------------
#
# -------------Iteration-- 67 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89769245]
#  [0.88474967]
#  [0.89690816]]
# -------------Iteration-- 67 Ends---------------
#
# -------------Iteration-- 68 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89761076]
#  [0.88466744]
#  [0.89682551]]
# -------------Iteration-- 68 Ends---------------
#
# -------------Iteration-- 69 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89753114]
#  [0.88458728]
#  [0.89674494]]
# -------------Iteration-- 69 Ends---------------
#
# -------------Iteration-- 70 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89745353]
#  [0.88450915]
#  [0.8966664 ]]
# -------------Iteration-- 70 Ends---------------
#
# -------------Iteration-- 71 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.8973779 ]
#  [0.88443299]
#  [0.89658985]]
# -------------Iteration-- 71 Ends---------------
#
# -------------Iteration-- 72 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.8973042 ]
#  [0.88435877]
#  [0.89651524]]
# -------------Iteration-- 72 Ends---------------
#
# -------------Iteration-- 73 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89723238]
#  [0.88428643]
#  [0.89644252]]
# -------------Iteration-- 73 Ends---------------
#
# -------------Iteration-- 74 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.8971624 ]
#  [0.88421594]
#  [0.89637166]]
# -------------Iteration-- 74 Ends---------------
#
# -------------Iteration-- 75 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89709422]
#  [0.88414725]
#  [0.89630261]]
# -------------Iteration-- 75 Ends---------------
#
# -------------Iteration-- 76 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89702779]
#  [0.88408031]
#  [0.89623532]]
# -------------Iteration-- 76 Ends---------------
#
# -------------Iteration-- 77 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89696308]
#  [0.8840151 ]
#  [0.89616977]]
# -------------Iteration-- 77 Ends---------------
#
# -------------Iteration-- 78 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89690005]
#  [0.88395156]
#  [0.89610589]]
# -------------Iteration-- 78 Ends---------------
#
# -------------Iteration-- 79 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89683865]
#  [0.88388965]
#  [0.89604367]]
# -------------Iteration-- 79 Ends---------------
#
# -------------Iteration-- 80 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89677884]
#  [0.88382935]
#  [0.89598305]]
# -------------Iteration-- 80 Ends---------------
#
# -------------Iteration-- 81 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89672059]
#  [0.8837706 ]
#  [0.89592399]]
# -------------Iteration-- 81 Ends---------------
#
# -------------Iteration-- 82 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89666387]
#  [0.88371338]
#  [0.89586647]]
# -------------Iteration-- 82 Ends---------------
#
# -------------Iteration-- 83 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89660862]
#  [0.88365764]
#  [0.89581044]]
# -------------Iteration-- 83 Ends---------------
#
# -------------Iteration-- 84 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89655483]
#  [0.88360334]
#  [0.89575587]]
# -------------Iteration-- 84 Ends---------------
#
# -------------Iteration-- 85 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89650244]
#  [0.88355047]
#  [0.89570273]]
# -------------Iteration-- 85 Ends---------------
#
# -------------Iteration-- 86 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89645144]
#  [0.88349896]
#  [0.89565097]]
# -------------Iteration-- 86 Ends---------------
#
# -------------Iteration-- 87 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89640178]
#  [0.88344881]
#  [0.89560056]]
# -------------Iteration-- 87 Ends---------------
#
# -------------Iteration-- 88 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89635343]
#  [0.88339996]
#  [0.89555147]]
# -------------Iteration-- 88 Ends---------------
#
# -------------Iteration-- 89 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89630636]
#  [0.8833524 ]
#  [0.89550367]]
# -------------Iteration-- 89 Ends---------------
#
# -------------Iteration-- 90 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89626054]
#  [0.88330608]
#  [0.89545713]]
# -------------Iteration-- 90 Ends---------------
#
# -------------Iteration-- 91 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89621593]
#  [0.88326098]
#  [0.89541181]]
# -------------Iteration-- 91 Ends---------------
#
# -------------Iteration-- 92 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89617251]
#  [0.88321706]
#  [0.89536768]]
# -------------Iteration-- 92 Ends---------------
#
# -------------Iteration-- 93 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89613025]
#  [0.8831743 ]
#  [0.89532472]]
# -------------Iteration-- 93 Ends---------------
#
# -------------Iteration-- 94 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89608911]
#  [0.88313267]
#  [0.89528289]]
# -------------Iteration-- 94 Ends---------------
#
# -------------Iteration-- 95 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89604907]
#  [0.88309213]
#  [0.89524217]]
# -------------Iteration-- 95 Ends---------------
#
# -------------Iteration-- 96 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89601011]
#  [0.88305267]
#  [0.89520253]]
# -------------Iteration-- 96 Ends---------------
#
# -------------Iteration-- 97 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89597218]
#  [0.88301425]
#  [0.89516394]]
# -------------Iteration-- 97 Ends---------------
#
# -------------Iteration-- 98 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89593528]
#  [0.88297684]
#  [0.89512638]]
# -------------Iteration-- 98 Ends---------------
#
# -------------Iteration-- 99 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89589937]
#  [0.88294043]
#  [0.89508981]]
# -------------Iteration-- 99 Ends---------------
#
# -------------Iteration-- 100 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89586442]
#  [0.88290498]
#  [0.89505422]]
# -------------Iteration-- 100 Ends---------------
#
# -------------Iteration-- 101 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89583042]
#  [0.88287048]
#  [0.89501957]]
# -------------Iteration-- 101 Ends---------------
#
# -------------Iteration-- 102 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89579733]
#  [0.88283689]
#  [0.89498585]]
# -------------Iteration-- 102 Ends---------------
#
# -------------Iteration-- 103 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89576514]
#  [0.88280419]
#  [0.89495303]]
# -------------Iteration-- 103 Ends---------------
#
# -------------Iteration-- 104 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89573382]
#  [0.88277237]
#  [0.89492108]]
# -------------Iteration-- 104 Ends---------------
#
# -------------Iteration-- 105 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89570335]
#  [0.88274139]
#  [0.89488999]]
# -------------Iteration-- 105 Ends---------------
#
# -------------Iteration-- 106 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89567371]
#  [0.88271124]
#  [0.89485974]]
# -------------Iteration-- 106 Ends---------------
#
# -------------Iteration-- 107 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89564487]
#  [0.88268189]
#  [0.89483029]]
# -------------Iteration-- 107 Ends---------------
#
# -------------Iteration-- 108 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89561681]
#  [0.88265332]
#  [0.89480163]]
# -------------Iteration-- 108 Ends---------------
#
# -------------Iteration-- 109 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89558952]
#  [0.88262552]
#  [0.89477375]]
# -------------Iteration-- 109 Ends---------------
#
# -------------Iteration-- 110 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89556297]
#  [0.88259846]
#  [0.89474661]]
# -------------Iteration-- 110 Ends---------------
#
# -------------Iteration-- 111 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89553715]
#  [0.88257213]
#  [0.8947202 ]]
# -------------Iteration-- 111 Ends---------------
#
# -------------Iteration-- 112 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89551203]
#  [0.88254649]
#  [0.8946945 ]]
# -------------Iteration-- 112 Ends---------------
#
# -------------Iteration-- 113 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.8954876 ]
#  [0.88252155]
#  [0.89466949]]
# -------------Iteration-- 113 Ends---------------
#
# -------------Iteration-- 114 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89546384]
#  [0.88249727]
#  [0.89464516]]
# -------------Iteration-- 114 Ends---------------
#
# -------------Iteration-- 115 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89544073]
#  [0.88247365]
#  [0.89462148]]
# -------------Iteration-- 115 Ends---------------
#
# -------------Iteration-- 116 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89541826]
#  [0.88245065]
#  [0.89459845]]
# -------------Iteration-- 116 Ends---------------
#
# -------------Iteration-- 117 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.8953964 ]
#  [0.88242828]
#  [0.89457603]]
# -------------Iteration-- 117 Ends---------------
#
# -------------Iteration-- 118 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89537515]
#  [0.8824065 ]
#  [0.89455422]]
# -------------Iteration-- 118 Ends---------------
#
# -------------Iteration-- 119 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89535448]
#  [0.88238531]
#  [0.894533  ]]
# -------------Iteration-- 119 Ends---------------
#
# -------------Iteration-- 120 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89533438]
#  [0.88236469]
#  [0.89451235]]
# -------------Iteration-- 120 Ends---------------
#
# -------------Iteration-- 121 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89531483]
#  [0.88234462]
#  [0.89449226]]
# -------------Iteration-- 121 Ends---------------
#
# -------------Iteration-- 122 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89529583]
#  [0.88232509]
#  [0.89447272]]
# -------------Iteration-- 122 Ends---------------
#
# -------------Iteration-- 123 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89527735]
#  [0.88230608]
#  [0.8944537 ]]
# -------------Iteration-- 123 Ends---------------
#
# -------------Iteration-- 124 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89525938]
#  [0.88228759]
#  [0.8944352 ]]
# -------------Iteration-- 124 Ends---------------
#
# -------------Iteration-- 125 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89524191]
#  [0.88226959]
#  [0.8944172 ]]
# -------------Iteration-- 125 Ends---------------
#
# -------------Iteration-- 126 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89522493]
#  [0.88225207]
#  [0.89439969]]
# -------------Iteration-- 126 Ends---------------
#
# -------------Iteration-- 127 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89520842]
#  [0.88223503]
#  [0.89438266]]
# -------------Iteration-- 127 Ends---------------
#
# -------------Iteration-- 128 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89519236]
#  [0.88221845]
#  [0.89436608]]
# -------------Iteration-- 128 Ends---------------
#
# -------------Iteration-- 129 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89517676]
#  [0.88220231]
#  [0.89434996]]
# -------------Iteration-- 129 Ends---------------
#
# -------------Iteration-- 130 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89516158]
#  [0.8821866 ]
#  [0.89433427]]
# -------------Iteration-- 130 Ends---------------
#
# -------------Iteration-- 131 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89514684]
#  [0.88217132]
#  [0.89431902]]
# -------------Iteration-- 131 Ends---------------
#
# -------------Iteration-- 132 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.8951325 ]
#  [0.88215645]
#  [0.89430417]]
# -------------Iteration-- 132 Ends---------------
#
# -------------Iteration-- 133 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89511856]
#  [0.88214198]
#  [0.89428973]]
# -------------Iteration-- 133 Ends---------------
#
# -------------Iteration-- 134 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89510502]
#  [0.88212789]
#  [0.89427568]]
# -------------Iteration-- 134 Ends---------------
#
# -------------Iteration-- 135 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89509185]
#  [0.88211419]
#  [0.89426202]]
# -------------Iteration-- 135 Ends---------------
#
# -------------Iteration-- 136 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89507905]
#  [0.88210085]
#  [0.89424872]]
# -------------Iteration-- 136 Ends---------------
#
# -------------Iteration-- 137 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89506661]
#  [0.88208788]
#  [0.89423579]]
# -------------Iteration-- 137 Ends---------------
#
# -------------Iteration-- 138 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89505453]
#  [0.88207525]
#  [0.89422321]]
# -------------Iteration-- 138 Ends---------------
#
# -------------Iteration-- 139 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89504278]
#  [0.88206296]
#  [0.89421097]]
# -------------Iteration-- 139 Ends---------------
#
# -------------Iteration-- 140 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89503136]
#  [0.882051  ]
#  [0.89419906]]
# -------------Iteration-- 140 Ends---------------
#
# -------------Iteration-- 141 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89502027]
#  [0.88203936]
#  [0.89418748]]
# -------------Iteration-- 141 Ends---------------
#
# -------------Iteration-- 142 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89500948]
#  [0.88202804]
#  [0.89417622]]
# -------------Iteration-- 142 Ends---------------
#
# -------------Iteration-- 143 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89499901]
#  [0.88201702]
#  [0.89416526]]
# -------------Iteration-- 143 Ends---------------
#
# -------------Iteration-- 144 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89498882]
#  [0.88200629]
#  [0.8941546 ]]
# -------------Iteration-- 144 Ends---------------
#
# -------------Iteration-- 145 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89497893]
#  [0.88199585]
#  [0.89414423]]
# -------------Iteration-- 145 Ends---------------
#
# -------------Iteration-- 146 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89496932]
#  [0.88198569]
#  [0.89413414]]
# -------------Iteration-- 146 Ends---------------
#
# -------------Iteration-- 147 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89495998]
#  [0.88197581]
#  [0.89412433]]
# -------------Iteration-- 147 Ends---------------
#
# -------------Iteration-- 148 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89495091]
#  [0.88196619]
#  [0.89411478]]
# -------------Iteration-- 148 Ends---------------
#
# -------------Iteration-- 149 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89494209]
#  [0.88195682]
#  [0.8941055 ]]
# -------------Iteration-- 149 Ends---------------
#
# -------------Iteration-- 150 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89493352]
#  [0.88194771]
#  [0.89409647]]
# -------------Iteration-- 150 Ends---------------
#
# -------------Iteration-- 151 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.8949252 ]
#  [0.88193884]
#  [0.89408768]]
# -------------Iteration-- 151 Ends---------------
#
# -------------Iteration-- 152 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89491712]
#  [0.88193021]
#  [0.89407913]]
# -------------Iteration-- 152 Ends---------------
#
# -------------Iteration-- 153 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89490927]
#  [0.88192181]
#  [0.89407082]]
# -------------Iteration-- 153 Ends---------------
#
# -------------Iteration-- 154 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89490164]
#  [0.88191363]
#  [0.89406273]]
# -------------Iteration-- 154 Ends---------------
#
# -------------Iteration-- 155 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89489424]
#  [0.88190567]
#  [0.89405486]]
# -------------Iteration-- 155 Ends---------------
#
# -------------Iteration-- 156 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89488704]
#  [0.88189792]
#  [0.89404721]]
# -------------Iteration-- 156 Ends---------------
#
# -------------Iteration-- 157 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89488005]
#  [0.88189038]
#  [0.89403977]]
# -------------Iteration-- 157 Ends---------------
#
# -------------Iteration-- 158 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89487327]
#  [0.88188304]
#  [0.89403252]]
# -------------Iteration-- 158 Ends---------------
#
# -------------Iteration-- 159 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89486667]
#  [0.8818759 ]
#  [0.89402548]]
# -------------Iteration-- 159 Ends---------------
#
# -------------Iteration-- 160 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89486027]
#  [0.88186894]
#  [0.89401862]]
# -------------Iteration-- 160 Ends---------------
#
# -------------Iteration-- 161 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89485406]
#  [0.88186217]
#  [0.89401196]]
# -------------Iteration-- 161 Ends---------------
#
# -------------Iteration-- 162 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89484802]
#  [0.88185558]
#  [0.89400547]]
# -------------Iteration-- 162 Ends---------------
#
# -------------Iteration-- 163 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89484216]
#  [0.88184917]
#  [0.89399916]]
# -------------Iteration-- 163 Ends---------------
#
# -------------Iteration-- 164 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89483647]
#  [0.88184292]
#  [0.89399303]]
# -------------Iteration-- 164 Ends---------------
#
# -------------Iteration-- 165 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89483095]
#  [0.88183684]
#  [0.89398706]]
# -------------Iteration-- 165 Ends---------------
#
# -------------Iteration-- 166 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89482558]
#  [0.88183092]
#  [0.89398125]]
# -------------Iteration-- 166 Ends---------------
#
# -------------Iteration-- 167 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89482038]
#  [0.88182516]
#  [0.8939756 ]]
# -------------Iteration-- 167 Ends---------------
#
# -------------Iteration-- 168 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89481532]
#  [0.88181955]
#  [0.8939701 ]]
# -------------Iteration-- 168 Ends---------------
#
# -------------Iteration-- 169 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89481041]
#  [0.88181408]
#  [0.89396475]]
# -------------Iteration-- 169 Ends---------------
#
# -------------Iteration-- 170 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89480565]
#  [0.88180876]
#  [0.89395955]]
# -------------Iteration-- 170 Ends---------------
#
# -------------Iteration-- 171 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89480103]
#  [0.88180358]
#  [0.89395449]]
# -------------Iteration-- 171 Ends---------------
#
# -------------Iteration-- 172 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89479654]
#  [0.88179854]
#  [0.89394956]]
# -------------Iteration-- 172 Ends---------------
#
# -------------Iteration-- 173 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89479219]
#  [0.88179363]
#  [0.89394477]]
# -------------Iteration-- 173 Ends---------------
#
# -------------Iteration-- 174 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89478797]
#  [0.88178885]
#  [0.89394011]]
# -------------Iteration-- 174 Ends---------------
#
# -------------Iteration-- 175 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89478387]
#  [0.88178419]
#  [0.89393557]]
# -------------Iteration-- 175 Ends---------------
#
# -------------Iteration-- 176 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89477989]
#  [0.88177965]
#  [0.89393116]]
# -------------Iteration-- 176 Ends---------------
#
# -------------Iteration-- 177 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89477603]
#  [0.88177523]
#  [0.89392687]]
# -------------Iteration-- 177 Ends---------------
#
# -------------Iteration-- 178 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89477229]
#  [0.88177093]
#  [0.89392269]]
# -------------Iteration-- 178 Ends---------------
#
# -------------Iteration-- 179 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89476865]
#  [0.88176674]
#  [0.89391863]]
# -------------Iteration-- 179 Ends---------------
#
# -------------Iteration-- 180 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89476513]
#  [0.88176265]
#  [0.89391467]]
# -------------Iteration-- 180 Ends---------------
#
# -------------Iteration-- 181 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89476171]
#  [0.88175868]
#  [0.89391083]]
# -------------Iteration-- 181 Ends---------------
#
# -------------Iteration-- 182 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.8947584 ]
#  [0.8817548 ]
#  [0.89390708]]
# -------------Iteration-- 182 Ends---------------
#
# -------------Iteration-- 183 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89475519]
#  [0.88175103]
#  [0.89390344]]
# -------------Iteration-- 183 Ends---------------
#
# -------------Iteration-- 184 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89475207]
#  [0.88174735]
#  [0.89389989]]
# -------------Iteration-- 184 Ends---------------
#
# -------------Iteration-- 185 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89474905]
#  [0.88174377]
#  [0.89389645]]
# -------------Iteration-- 185 Ends---------------
#
# -------------Iteration-- 186 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89474612]
#  [0.88174028]
#  [0.89389309]]
# -------------Iteration-- 186 Ends---------------
#
# -------------Iteration-- 187 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89474328]
#  [0.88173687]
#  [0.89388982]]
# -------------Iteration-- 187 Ends---------------
#
# -------------Iteration-- 188 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89474053]
#  [0.88173356]
#  [0.89388664]]
# -------------Iteration-- 188 Ends---------------
#
# -------------Iteration-- 189 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89473786]
#  [0.88173033]
#  [0.89388355]]
# -------------Iteration-- 189 Ends---------------
#
# -------------Iteration-- 190 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89473527]
#  [0.88172718]
#  [0.89388054]]
# -------------Iteration-- 190 Ends---------------
#
# -------------Iteration-- 191 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89473277]
#  [0.88172411]
#  [0.89387761]]
# -------------Iteration-- 191 Ends---------------
#
# -------------Iteration-- 192 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89473034]
#  [0.88172112]
#  [0.89387476]]
# -------------Iteration-- 192 Ends---------------
#
# -------------Iteration-- 193 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89472798]
#  [0.88171821]
#  [0.89387198]]
# -------------Iteration-- 193 Ends---------------
#
# -------------Iteration-- 194 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89472571]
#  [0.88171537]
#  [0.89386928]]
# -------------Iteration-- 194 Ends---------------
#
# -------------Iteration-- 195 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.8947235 ]
#  [0.8817126 ]
#  [0.89386665]]
# -------------Iteration-- 195 Ends---------------
#
# -------------Iteration-- 196 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89472136]
#  [0.88170989]
#  [0.89386409]]
# -------------Iteration-- 196 Ends---------------
#
# -------------Iteration-- 197 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89471929]
#  [0.88170726]
#  [0.8938616 ]]
# -------------Iteration-- 197 Ends---------------
#
# -------------Iteration-- 198 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89471729]
#  [0.88170469]
#  [0.89385918]]
# -------------Iteration-- 198 Ends---------------
#
# -------------Iteration-- 199 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89471534]
#  [0.88170219]
#  [0.89385682]]
# -------------Iteration-- 199 Ends---------------
#
# -------------Iteration-- 200 Starts-------------
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89471347]
#  [0.88169975]
#  [0.89385452]]
# -------------Iteration-- 200 Ends---------------
#
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89471347]
#  [0.88169975]
#  [0.89385452]]
